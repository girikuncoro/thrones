# %%
from bs4 import BeautifulSoup
import urllib
import nltk
import re
from pprint import pprint
import csv
from collections import OrderedDict

# %%
#url = 'http://gameofthrones.wikia.com/wiki/Daenerys_Targaryen'
url = 'http://gameofthrones.wikia.com/wiki/Gilly'
page = urllib.urlopen(url)
soup = BeautifulSoup(page.read())

corpus = soup.get_text()
print url.split('/')[-1].replace('_',' ')

key_words = ["Season(s)", "First seen", "Last seen", "Appeared in", "Mentioned in", "Titles", "Also known as", "Status",
             "Age", "Date of birth", "Death", "Origin", "Allegiance", "Culture", "Religion", "Family", "Portrayed by"]
for word in key_words:
    start = corpus.find(word)
    start_content = start + len(word) + 1
    end = corpus.find("\n\n",start_content)
    if corpus[start_content] == '{' or corpus[start_content] == '\n':
        continue
    #print word + ": " + corpus[start_content:end]

print soup
# Out:
# Gilly
# <!DOCTYPE doctype html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport">
# <meta content="MediaWiki 1.19.24" name="generator"/>
# <meta content="Game of Thrones Wiki,gameofthrones,Gilly,Mhysa,Breaker of Chains,The North Remembers,The Night Lands,What is Dead May Never Die,Valar Morghulis,Walk of Punishment,And Now His Watch is Ended,The Climb,Second Sons" name="keywords"/>
# <meta content="Gilly is a major character in the fourth and fifth seasons. She initially appeared as a..." name="description"/>
# <meta content="dS0TsKnwenO7Pgwq42CoGUFqwE1FmFZGLCI2Nbf3Atc" name="google-site-verification"/>
# <link href="http://gameofthrones.wikia.com/wiki/Gilly" rel="canonical"/>
# <link href="/wiki/Gilly?action=edit" rel="alternate" title="Edit" type="application/x-wiki"/>
# ...

# %%
new_soup = soup.find(text="Season(s)")

parent = new_soup.find_parent("td")
print parent.find_next_sibling("td").get_text()
# Out:
# 1, 2, 3, 4, 5

# %%
from bs4 import BeautifulSoup
import urllib
import nltk
import re
from pprint import pprint
import csv
from collections import OrderedDict

key_words = ["Season(s)", "First seen", "Last seen", "Appeared in", "Mentioned in", "Titles", "Also known as", "Status",
             "Age", "Date of birth", "Death", "Origin", "Allegiance", "Culture", "Religion", "Family", "Portrayed by"]

char_list = open('char_list2.txt', 'r')
info = OrderedDict()
count_char = 1

with open('throne_raw2.csv', 'w') as csvfile:
    # Write CSV Header
    fieldnames = list(key_words)
    fieldnames.insert(0, 'Name')
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames) 
    writer.writeheader()

    # Scraping the web pages
    for url in char_list:  
        page = urllib.urlopen(url)
        soup = BeautifulSoup(page.read())
        # Find character information
        info['Name'] = url.split('/')[-1].replace('_',' ')
        
        for word in key_words:
            keys = soup.find(text=word)

            if keys is not None:
                parent = keys.find_parent("td")
                if parent is not None:
                    value = parent.find_next_sibling("td").get_text()
                    if '{{{' in value:
                        info[word] = ''
                    else:
                        info[word] = value
                else:
                    info[word] = ''
            else:
                info[word] = ''
        
        try:
            writer.writerow(info)
        except:
            continue
        print "Crawled {0} characters".format(count_char)
        count_char += 1
        
char_list.close()
print "Processing completed"
# Out:
# Crawled 1 characters
# Crawled 2 characters
# Crawled 3 characters
# Crawled 4 characters
# Crawled 5 characters
# Crawled 6 characters
# Crawled 7 characters
# Crawled 8 characters
# Crawled 9 characters
# Crawled 10 characters
# Crawled 11 characters
# Crawled 12 characters
# Crawled 13 characters
# Crawled 14 characters
# Crawled 15 characters
# Crawled 16 characters
# Crawled 17 characters
# Crawled 18 characters
# Crawled 19 characters
# Crawled 20 characters
# Crawled 21 characters
# Crawled 22 characters
# Crawled 23 characters
# Crawled 24 characters
# Crawled 25 characters
# Crawled 26 characters
# Crawled 27 characters
# Crawled 28 characters
# Crawled 29 characters
# Crawled 30 characters
# Crawled 31 characters
# Crawled 32 characters
# Crawled 33 characters
# Crawled 34 characters
# Crawled 35 characters
# Crawled 36 characters
# Crawled 37 characters
# Crawled 38 characters
# Crawled 39 characters
# Crawled 40 characters
# Crawled 41 characters
# Processing completed

# %%
# Write to CSV
with open('throne_raw.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=info.keys()) # CSV Header
    writer.writeheader()
    
    for char_info in info_list:
        writer.writerow(char_info.values())
        #print char_info.values()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-cb54b127c822> in <module>()
#       5
#       6     for char_info in info_list:
# ----> 7         writer.writerow(char_info.values())
#       8         #print char_info.values()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/csv.pyc in writerow(self, rowdict)
#     146
#     147     def writerow(self, rowdict):
# --> 148         return self.writer.writerow(self._dict_to_list(rowdict))
#     149
#     150     def writerows(self, rowdicts):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/csv.pyc in _dict_to_list(self, rowdict)
#     142             if wrong_fields:
#     143                 raise ValueError("dict contains fields not in fieldnames: " +
# --> 144                                  ", ".join(wrong_fields))
# ...

# %%
print info.keys()
# Out:
# ['Name', 'Season(s)', 'First seen', 'Last seen', 'Appeared in', 'Mentioned in', 'Titles', 'Also known as', 'Status', 'Age', 'Date of birth', 'Death', 'Origin', 'Allegiance', 'Culture', 'Religion', 'Family', 'Portrayed by']
